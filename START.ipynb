# %% [markdown]
# # CTG 본선 원클릭 실행
# PyTorch / Python 3.10 이상 커널을 선택한 후 **Run All**을 누르세요. 아래 입력창에서 데이터 폴더·결과 폴더를 지정하고 **전체 실행**을 누르면 됩니다. 코드 편집은 필요 없습니다. 원천 데이터는 이 노트북 폴더에 넣지 마세요.
# mock 모드는 전 데이터를 읽되 학습 예산을 줄입니다. mock 결과는 연구 성능으로 사용하지 않습니다.

# %%
from launcher_ui import launch
launch()
